# %% [markdown]
# ** Préambule ** L'objectif de ce TP est de mettre en pratique quelques algorithmes de reconstruction d'image. Pour ce faire, nous nous intéressons à des variantes d'un algorithme dit de factorisation non-négative, où l'on cherche à approcher au mieux une matrice en un produit de deux matrices de rang faible à éléments non-négatifs.
#
# ** NB ** Il vous est demandé d'insérer vos commentaires et codes ** uniquement ** dans ce fichier et de le sauvegarder sous la forme TP_2_nom1_nom2.ipynb. Cela produira automatiquement votre compte-rendu de ce TP.

# %%
# Chargement des packages nécessaires
using Images, Colors, StatsBase
# Cette étape est à réaliser deux fois consécutivement avant de s'attaquer au reste du TP

# %%
# Chargement de l'image test parmi polar_bear.jpg 
imgc  = load("polar_bear.jpg")
# Out:
# 600×900 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.69,0.718,0.788)   …  RGB{N0f8}(0.729,0.749,0.824)
#  RGB{N0f8}(0.745,0.773,0.843)     RGB{N0f8}(0.749,0.769,0.843)
#  RGB{N0f8}(0.722,0.741,0.82)      RGB{N0f8}(0.784,0.796,0.871)
#  RGB{N0f8}(0.769,0.788,0.867)     RGB{N0f8}(0.753,0.765,0.839)
#  RGB{N0f8}(0.773,0.792,0.867)     RGB{N0f8}(0.773,0.792,0.867)
#  RGB{N0f8}(0.733,0.753,0.827)  …  RGB{N0f8}(0.718,0.737,0.812)
#  RGB{N0f8}(0.737,0.761,0.824)     RGB{N0f8}(0.753,0.78,0.851)
#  RGB{N0f8}(0.733,0.757,0.82)      RGB{N0f8}(0.773,0.8,0.871)
#  RGB{N0f8}(0.737,0.757,0.831)     RGB{N0f8}(0.733,0.761,0.831)
#  RGB{N0f8}(0.702,0.722,0.796)     RGB{N0f8}(0.745,0.773,0.843)
#  RGB{N0f8}(0.741,0.769,0.839)  …  RGB{N0f8}(0.733,0.761,0.824)
#  RGB{N0f8}(0.737,0.765,0.835)     RGB{N0f8}(0.749,0.776,0.839)
#  RGB{N0f8}(0.722,0.741,0.816)     RGB{N0f8}(0.733,0.757,0.82)
#  ⋮                             ⋱
#  RGB{N0f8}(0.686,0.706,0.78)      RGB{N0f8}(0.816,0.827,0.886)
#  RGB{N0f8}(0.757,0.776,0.851)     RGB{N0f8}(0.816,0.827,0.886)
#  RGB{N0f8}(0.784,0.804,0.878)  …  RGB{N0f8}(0.808,0.831,0.886)
#  RGB{N0f8}(0.753,0.773,0.847)     RGB{N0f8}(0.827,0.851,0.906)
#  RGB{N0f8}(0.796,0.816,0.89)      RGB{N0f8}(0.808,0.831,0.894)
#  RGB{N0f8}(0.737,0.757,0.831)     RGB{N0f8}(0.827,0.851,0.914)
#  RGB{N0f8}(0.78,0.808,0.878)      RGB{N0f8}(0.824,0.847,0.902)
#  RGB{N0f8}(0.757,0.784,0.855)  …  RGB{N0f8}(0.816,0.839,0.894)
#  RGB{N0f8}(0.776,0.8,0.863)       RGB{N0f8}(0.824,0.851,0.914)
#  RGB{N0f8}(0.745,0.765,0.839)     RGB{N0f8}(0.796,0.824,0.886)
#  RGB{N0f8}(0.765,0.792,0.867)     RGB{N0f8}(0.792,0.816,0.878)
#  RGB{N0f8}(0.769,0.796,0.871)     RGB{N0f8}(0.722,0.745,0.808)

# %%
# Si le TP est réalisé sur la Juliabox
#imgc=imgc[100:300,200:500];

img   = convert(Array{Gray},imgc);   # Conversion de l'image en niveau de gris
M     = Float32.(img);  # M est la matrice des niveaux de gris
imhsv = colorview(Gray, float(M));     # Affichage
tmp2 = @view imhsv[:,:]
# Out:
# 600×900 view(reinterpret(reshape, Gray{Float32}, ::Matrix{Float32}), :, :) with eltype Gray{Float32}:
#  Gray{Float32}(0.717647)  Gray{Float32}(0.74902)   …  Gray{Float32}(0.752941)
#  Gray{Float32}(0.772549)  Gray{Float32}(0.717647)     Gray{Float32}(0.772549)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.752941)     Gray{Float32}(0.8)
#  Gray{Float32}(0.792157)  Gray{Float32}(0.756863)     Gray{Float32}(0.768627)
#  Gray{Float32}(0.796078)  Gray{Float32}(0.776471)     Gray{Float32}(0.796078)
#  Gray{Float32}(0.756863)  Gray{Float32}(0.760784)  …  Gray{Float32}(0.741176)
#  Gray{Float32}(0.760784)  Gray{Float32}(0.780392)     Gray{Float32}(0.780392)
#  Gray{Float32}(0.756863)  Gray{Float32}(0.752941)     Gray{Float32}(0.8)
#  Gray{Float32}(0.760784)  Gray{Float32}(0.768627)     Gray{Float32}(0.760784)
#  Gray{Float32}(0.72549)   Gray{Float32}(0.752941)     Gray{Float32}(0.772549)
#  Gray{Float32}(0.768627)  Gray{Float32}(0.741176)  …  Gray{Float32}(0.760784)
#  Gray{Float32}(0.764706)  Gray{Float32}(0.756863)     Gray{Float32}(0.776471)
#  Gray{Float32}(0.745098)  Gray{Float32}(0.74902)      Gray{Float32}(0.756863)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.709804)  Gray{Float32}(0.807843)     Gray{Float32}(0.831373)
#  Gray{Float32}(0.780392)  Gray{Float32}(0.815686)     Gray{Float32}(0.831373)
#  Gray{Float32}(0.807843)  Gray{Float32}(0.788235)  …  Gray{Float32}(0.831373)
#  Gray{Float32}(0.776471)  Gray{Float32}(0.803922)     Gray{Float32}(0.85098)
#  Gray{Float32}(0.819608)  Gray{Float32}(0.772549)     Gray{Float32}(0.831373)
#  Gray{Float32}(0.760784)  Gray{Float32}(0.796078)     Gray{Float32}(0.85098)
#  Gray{Float32}(0.807843)  Gray{Float32}(0.784314)     Gray{Float32}(0.847059)
#  Gray{Float32}(0.784314)  Gray{Float32}(0.796078)  …  Gray{Float32}(0.839216)
#  Gray{Float32}(0.8)       Gray{Float32}(0.784314)     Gray{Float32}(0.85098)
#  Gray{Float32}(0.768627)  Gray{Float32}(0.772549)     Gray{Float32}(0.823529)
#  Gray{Float32}(0.792157)  Gray{Float32}(0.776471)     Gray{Float32}(0.815686)
#  Gray{Float32}(0.796078)  Gray{Float32}(0.811765)     Gray{Float32}(0.745098)

# %%
#
# Paramètres utiles par la suite
#
m     = size(M,1);
n     = size(M,2);
erank = 150;        # rang estime des matrices X et Y 
maxit = 1000;      # nombre maximal d'iterations 
X=rand(Float32, (m, erank));
Y=rand(Float32,(erank, n));

# %% [markdown]
# **Question 1):** Implanter l'algorithme du théorème 1 de "Algorithms and Applications for Approximate Nonnegative Matrix Factorization" de Lee et Seung.
# Mentionner les propriétés principales de cet algorithme.
#
# <!-- Il est possible de prouver que les mises à jour
#     $Y_{ij}\leftarrow Y_{ij} \frac{(X'M)_{ij}}{(X'XY)_{ij}}$
# et
# $ X_{ij} \leftarrow X_{ij}\frac{(MY')_{ij}}{(XYY')_{ij}}$
# donnent lieu à des itérations telles que $\Vert{M-XY}\Vert_F$ décroît.
# Réaliser 1000 itérations de cet algorithme partant d'une valeur aléatoire pour $X \in \mathbb{R}^{m \times r}$ et $Y \in \mathbb{R}^{r \times n}$. Donner une condition sous laquelle les itérés restent non négatifs. -->

# %%
# Inserer votre code ici
k=0;
norms = [];
while k < maxit
    k=k+1
    A=X'*M;
    
    
    C=X'*X;
    C=C*Y;
    
    
    Y=Y.*A./C;
    B=M*Y';
    D=X*Y*Y';
    X=X.*B./D;
    
    frobenius_norm = norm(M-X*Y,2)
    
    push!(norms, frobenius_norm)
    



end
return(X,Y)

println("Vecteur des normes de Frobenius :")
println(norms)
# Out:
# Vecteur des normes de Frobenius :
# Any[57.568485f0, 57.49815f0, 57.434547f0, 57.3707f0, 57.30638f0, 57.241352f0, 57.175373f0, 57.10819f0, 57.03954f0, 56.96915f0, 56.896725f0, 56.82196f0, 56.74453f0, 56.66409f0, 56.580276f0, 56.4927f0, 56.40095f0, 56.3046f0, 56.203182f0, 56.09622f0, 55.9832f0, 55.863598f0, 55.736866f0, 55.60244f0, 55.459736f0, 55.308167f0, 55.147152f0, 54.97611f0, 54.794476f0, 54.60172f0, 54.397354f0, 54.180946f0, 53.952145f0, 53.710674f0, 53.456394f0, 53.189266f0, 52.909416f0, 52.61712f0, 52.31283f0, 51.99719f0, 51.67101f0, 51.335297f0, 50.991238f0, 50.64017f0, 50.28357f0, 49.923027f0, 49.560196f0, 49.19677f0, 48.83443f0, 48.47481f0, 48.119446f0, 47.769745f0, 47.426956f0, 47.092148f0, 46.766182f0, 46.449715f0, 46.143196f0, 45.84688f0, 45.56084f0, 45.28498f0, 45.019066f0, 44.762753f0, 44.515594f0, 44.277096f0, 44.046707f0, 43.823856f0, 43.607975f0, 43.398495f0, 43.194878f0, 42.996605f0, 42.8032f0, 42.61422f0, 42.42927f0, 42.247997f0, 42.070072f0, 41.89522f0, 41.723198f0, 41.553787f0, 41.386806f0, 41.222095f0, 41.059525f0, 40.89897f0, 40.740337f0, 40.58354f0, 40.42851f0, 40.27518f0, 40.123497f0, 39.97341f0, 39.82489f0, 39.677887f0, 39.532375f0, 39.38832f0, 39.2457f0, 39.10449f0, 38.96466f0, 38.8262f0, 38.689083f0, 38.553288f0, 38.418808f0, 38.285618f0, 38.153706f0, 38.02306f0, 37.893665f0, 37.765514f0, 37.63859f0, 37.512886f0, 37.388393f0, 37.2651f0, 37.142998f0, 37.022083f0, 36.902348f0, 36.78378f0, 36.666378f0, 36.550133f0, 36.43504f0, 
# %%
# Reconstruction de l'image issu du produit des facteurs et mise a l'echelle 
# Inserer votre code ici
J=zeros(m,n);
# Fin insertion
J=X*Y;
# Affichage
imhsv =  colorview(Gray,float(J));
tmp = @view imhsv[:,:]

imhsv =  colorview(Gray,float(X));
tmp = @view imhsv[:,:]
# Out:
# 600×150 view(reinterpret(reshape, Gray{Float32}, ::Matrix{Float32}), :, :) with eltype Gray{Float32}:
#  Gray{Float32}(0.36915)   …  Gray{Float32}(0.611933)
#  Gray{Float32}(0.258645)     Gray{Float32}(0.862071)
#  Gray{Float32}(0.302161)     Gray{Float32}(0.719637)
#  Gray{Float32}(0.575822)     Gray{Float32}(0.662327)
#  Gray{Float32}(0.468002)     Gray{Float32}(0.628691)
#  Gray{Float32}(0.355199)  …  Gray{Float32}(0.665648)
#  Gray{Float32}(0.544848)     Gray{Float32}(0.579605)
#  Gray{Float32}(0.535208)     Gray{Float32}(0.725682)
#  Gray{Float32}(0.408392)     Gray{Float32}(0.812746)
#  Gray{Float32}(0.401272)     Gray{Float32}(0.554035)
#  Gray{Float32}(0.408268)  …  Gray{Float32}(0.629688)
#  Gray{Float32}(0.148005)     Gray{Float32}(0.883342)
#  Gray{Float32}(0.424129)     Gray{Float32}(0.594685)
#  ⋮                        ⋱
#  Gray{Float32}(0.52738)      Gray{Float32}(1.20215)
#  Gray{Float32}(0.552654)     Gray{Float32}(0.948763)
#  Gray{Float32}(0.151443)  …  Gray{Float32}(1.41649)
#  Gray{Float32}(0.703772)     Gray{Float32}(0.854584)
#  Gray{Float32}(0.938532)     Gray{Float32}(0.981676)
#  Gray{Float32}(0.548279)     Gray{Float32}(0.930949)
#  Gray{Float32}(0.283378)     Gray{Float32}(0.790964)
#  Gray{Float32}(0.701015)  …  Gray{Float32}(0.81763)
#  Gray{Float32}(0.487229)     Gray{Float32}(0.72276)
#  Gray{Float32}(0.805959)     Gray{Float32}(0.333225)
#  Gray{Float32}(0.690221)     Gray{Float32}(0.687974)
#  Gray{Float32}(0.704077)     Gray{Float32}(1.19818)

# %% [markdown]
# **Question 2): ** Répeter les étapes précédentes en faisant varier le rang éstimé des matrices $X$ et $Y$ (variable "erank"). Qu'observez-vous?

# %% [markdown]
# **Question 3): ** Donner une interprétation des mises à jour
# $X = \max (0,MY'(YY')^+)$
# $Y = \max(0,(X'X)^+ X'M )$. Faire tourner un algorithme implantant ces itérations (Xu et al.).

# %%
# Inserer votre code ici

# Fin insertion

# %%
# Reconstruction de l'image et mise a l'echelle 
# Inserer votre code ici
J=zeros(m,n);
# Fin insertion 

# Affichage
imhsv = colorview(Gray,float(J));
tmp=@view imhsv[:,:]
# Out:
# 600×900 view(::Array{Gray{Float64},2}, :, :) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  ⋮                                       ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)

# %% [markdown]
# **Question 4): ** Répeter les étapes précédentes en faisant varier le rang éstimé des matrices $X$ et $Y$ (variable "erank"). Qu'observez-vous?
